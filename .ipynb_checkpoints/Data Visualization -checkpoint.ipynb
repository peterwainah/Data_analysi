# %% [markdown]
# # Visualization with Matplotlib

# %%
# importing required libraries
import numpy as np
import pandas as pd

# importing matplotlib
import matplotlib.pyplot as plt
# display plots in the notebook itself
# %matplotlib inline

# %% [markdown]
# # a)Matplotlib basics

# %%
height=[150,160,156,110]
weight=[50,30,100,30]
# draw the plot
plt.plot(height,weight)

# %% [markdown]
# ## Adding Title,Labels and Legends

# %%
# draw the plot
plt.plot(height,weight)
# add title
plt.title("Relationship between height and Weight")
# label x axis
plt.xlabel("Height")
# label y axis
plt.ylabel("Weight")
# Out:
# Text(0, 0.5, 'Weight')

# %%
calories_burnt= [54,90,10,33]
# draw plot for calories
plt.plot(calories_burnt)
# draw plot for weight
plt.plot(weight)

# %% [markdown]
# Adding ***legends** to differentiate plot

# %%
# draw plot for calories
plt.plot(calories_burnt)
# draw plot for weight
plt.plot(weight)
# add legend in lower right part of the figure
plt.legend(labels=['Calories Burnt', 'Weight'], loc='lower right')

# %% [markdown]
# * Note that in the above plot we are not able to understand that each of these values belong to different persons.
# * Look at the X axis , we can add labels to show that each belong to different persons
# * The labelled values on any axis is known as a **tick**.
# * You can use the xticks to change both the location of each tick and its label.

# %%
# draw plot
plt.plot(calories_burnt)
plt.plot(weight)
# add legend in the lower right part of the figure
plt.legend(labels=['Calories Burnt', 'weight'], loc='lower right')
# set labels for each of these persons
plt.xticks(ticks=[0,1,2,3], labels=['p1', 'p2' , 'p3', 'p4']);

# %%
# Changing color of plot line and making it doted
plt.plot(weight, 'y--')

# %%
# drawing green doted circles
plt.plot(weight, 'go')

# %% [markdown]
# # Creating sublots

# %%
# create 2 plots
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(6,6))
# plot on 0 row and 0 column
ax[0,0].plot(calories_burnt, 'go')
# plot on 0 row and 1 column
ax[0,1].plot(weight)
# set titles for subplots
ax[0,0].set_title("Calories Burnt")
ax[0,0].set_title("Weight")
# set ticks for each of these persons
ax[0,0].set_xticks(ticks=[0,1,2,3]);
ax[0,1].set_xticks(ticks=[0,1,2,3]);
# set labels for each of these persons
ax[0,0].set_xticklabels(labels=['p1', 'p2', 'p3', 'p4']);
ax[0,1].set_xticklabels(labels=['p1', 'p2', 'p3', 'p4']);

# %% [markdown]
# * Notice that in the above figure we have two empty plots, because we created 4 subplots(2 rows and 2 columns)
# * As a data scientist,atimes you may need to have common axis for all your subplots.This can be done using sharey parameters of subplot()

# %%
# create 2 plots
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(6,6), sharey=True)
# plot on 0 row and 0 column
ax[0].plot(calories_burnt, 'go')
# plot on 0 row and 1 column
ax[1].plot(weight)
# set titles for subplots
ax[0].set_title("Calories Burnt")
ax[1].set_title("Weight")
# set ticks for each of these persons
ax[0].set_xticks(ticks=[0,1,2,3]);
ax[1].set_xticks(ticks=[0,1,2,3]);
# set labels for each of these persons
ax[0].set_xticklabels(labels=['p1','p2','p3', 'p4']);
ax[1].set_xticklabels(labels=['p1','p2','p3','p4']);

# %% [markdown]
# # Case study for big mart sales

# %%
# read data set
Bm = pd.read_csv('data/bigmart_data.csv')
# drop null values
Bm = Bm.dropna(how="any")
Bm.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-86-d1b48dabd454> in <module>
#       1 # read data set
# ----> 2 Bm = pd.read_csv('data/bigmart_data.csv')
#       3 # drop null values
#       4 Bm = Bm.dropna(how="any")
#       5 Bm.head()
#
# TypeError: 'str' object is not callable

# %% [markdown]
# # Line Chart
# * LIne chart will denote mean price per item.lets have a look at the code
# * With some datasets you may want to understand changes in one variable as a function of time or similarly continuous variable.
# * In matplotlib, **line chart** is the default plot when using the plot()

# %%
price_by_item=Bm.groupby('Item_Type').Item_MRP.mean()[:10]
price_by_item
# Out:
# Item_Type
# Baking Goods             125.795653
# Breads                   141.300639
# Breakfast                134.090683
# Canned                   138.551179
# Dairy                    149.481471
# Frozen Foods             140.095830
# Fruits and Vegetables    145.418257
# Hard Drinks              140.102908
# Health and Hygiene       131.437324
# Household                149.884244
# Name: Item_MRP, dtype: float64

# %%
# mean price based on item type
price_by_item=Bm.groupby('Item_Type').Item_MRP.mean()[:10]
x = price_by_item.index.tolist()
y = price_by_item.values.tolist()

# set figure size
plt.figure(figsize=(14, 8))
# set title
plt.title('Mean price for each item type')
# set axis labels
plt.xlabel('Item Type')
plt.ylabel('Mean Price')
# set xticks
plt.xticks(labels=x, ticks=np.arange(len(x)))
plt.plot(x,y)

# %% [markdown]
# # Bar chart
# -Suppose we want to have a look at what is the mean sales for each outlet size
# -use plt.bar instead of plt.plot

# %%
# mean price based on item type
sales_by_outlet_size=Bm.groupby('Outlet_Size').Item_Outlet_Sales.mean()[:10]
x = sales_by_outlet_size.index.tolist()
y = sales_by_outlet_size.values.tolist()

# set figure size
plt.figure(figsize=(14, 8))
# set title
plt.title('Mean sales for each Outlet size')
# set axis labels
plt.xlabel('Outlet_Size')
plt.ylabel('Sales')
# set xticks
plt.xticks(labels=x, ticks=np.arange(len(x)))
#plt.bar(x,y)
# adding clor
plt.bar(x,y, color=['red', 'orange', 'magenta'])
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# # Histogram
# * **Distribution of item price**
# * Histograms are very common type of plots when we are looking at data like height and weight, stock prices,waiting time for a customer , etc which are continuous in nature.
# * Histograms data is plotted within a range against its frequency.

# %%
# title
plt.title('Item MRP (price) distribution')
# xlabel
plt.xlabel('Item_MRP')
# y label
plt.ylabel('Frequency')
# plot histogram
plt.hist(Bm['Item_MRP'], bins=20, color='lightblue');

# %% [markdown]
# # Box plots
# **Distribution of sales**
# * Box plots shows three quartile values of the distribution along extreme values
# * VIsualize distribution of item_outlet_sales of items

# %%
Bm_data = Bm[['Item_Outlet_Sales']]
# create oulier point shape
red_diamond = dict(markerfacecolor='r', marker='D')
# set title
plt.title('Item Sales distribution')
# make boxplot
plt.boxplot(Bm_data.values, labels=['Item Sales'], flierprops=red_diamond);

# %% [markdown]
# -Generating Item_Weight, Item_MRP distribution together

# %%
Bm_data =Bm [['Item_Weight', 'Item_MRP']]
# create outlier point shape
red_diamond = dict(markerfacecolor='r', marker='D')
# generate subplots
fig, ax = plt.subplots()
# make the boxplot
plt.boxplot(Bm_data.values, labels=['Item Weight', 'Item MRP(price)']);

# %% [markdown]
# # Violin plots
# **Density Distribution of item weights and item price**

# %%
Bm_data = Bm[['Item_Weight','Item_MRP']]
# generate subplots
fig, ax = plt.subplots()
# add labels to x axis
plt.xticks(ticks=[1,2], labels=['Item Weight', 'Item MRP'])
# make the violinplot
plt.violinplot(Bm_data.values);

# %% [markdown]
# # Scatter plots
# * **Relative distribution of item weight and its visibility**
# * it depicts the distribution of two variables using cloud of points where each point represent an observation in the dataset

# %%
# set label of axes
plt.xlabel('Item_Weight')
plt.ylabel('Item_Visibility')
# plot
plt.scatter(Bm["Item_Weight"][:200], Bm["Item_Visibility"][:200])

# %% [markdown]
# # Bubble PLots
# * **Relative distribution of sales, item price and item visibility**
# * Lets make a scatter plot of item_Outlet_Sales and  Item_MRP and make the size of bubbles by column Item_Visibility

# %%
# set label of axes
plt.xlabel('Item_MRP')
plt.ylabel('Item_Outlet_Sales')
# set title
plt.title('Item OUtlet Sales vs Item MRP (price)')
# plot
plt.scatter(Bm["Item_MRP"][:100], Bm["Item_Outlet_Sales"][:100], s=Bm["Item_Visibility"][:100]
# Out:
#   File "<ipython-input-52-48ad726dbbc7>", line 7
#     plt.scatter(Bm["Item_MRP"][:100], Bm["Item_Outlet_Sales"][:100], s=Bm["Item_Visibility"][:100]
#                                                                                                   ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# # VISUALIZATION WITH SEABORN

# %%
# importing seaborn required libraries
import seaborn as sns
sns.set()
sns.set(style="darkgrid")
# importing required libraries
import numpy as np
import pandas as pd
# importing matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
# read dataset
data_BM = pd.read_csv('data/bigmart_data.csv')
# drop null values
data_Bm = data_BM.dropna(how="any")
# multiply Item_Visibility by 100 to increase size
data_Bm["Visibility_Scaled"] = data_Bm["Item_Visibility"] * 100
# view the top results

data_BM.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %% [markdown]
# ## Line chart

# %%
# line plot using lineplot()
sns.lineplot(x="Item_Weight", y="Item_MRP",data=data_BM[:50]);

# %% [markdown]
# ## Barchart

# %%
sns.barplot(x="Item_Type", y="Item_MRP", data=data_BM[:5])
# Out:
# <AxesSubplot:xlabel='Item_Type', ylabel='Item_MRP'>

# %% [markdown]
# ## Histogram

# %%
sns.distplot(data_BM['Item_MRP'])
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='Density'>

# %% [markdown]
# ## Box plots

# %%
sns.boxplot(data_BM['Item_Outlet_Sales'], orient='vertical')
# Out:
# <AxesSubplot:xlabel='Item_Outlet_Sales'>

# %% [markdown]
# ## Violin plot

# %%
sns.violinplot(data_Bm['Item_Outlet_Sales'], orient='vertical', color='magenta')
# Out:
# <AxesSubplot:xlabel='Item_Outlet_Sales'>

# %% [markdown]
# # Scatter plot

# %%
# scatter plot
sns.relplot(x="Item_MRP", y="Item_Outlet_Sales", data=data_BM[:200], kind="scatter");

# %% [markdown]
# ## Hue semantic
# -we can also add another dimension to the plot by coloring the points according to a third variable.In seaborn is reffered to as using a "hue semantic"

# %%
sns.relplot(x="Item_MRP", y="Item_Outlet_Sales", hue="Item_Type", data=data_BM[:200]);

# %% [markdown]
# -Remember the line chart we created earlier?When Hue semantic is used a more complex line plots can be created
# -Int the following example different line plots for different ctgories of the Outlet size are made

# %%
sns.lineplot(x="Item_Weight", y="Item_MRP", hue='Outlet_Size', data=data_BM[:150]);

# %% [markdown]
# ## Bubble plot
# * We utilize the **hue** semantic to color bubbles by their item_visibility and at the same time use it as size of individual bubbles

# %%
sns.relplot(x="Item_MRP", y="Item_Outlet_Sales", data=data_BM[:200], kind="scatter", size="Item_Visibility", hue="Item_Visibility");

# %%
#subplots for each of the category of Outlet_Size
sns.relplot(x="Item_Weight", y="Item_Visibility", hue='Outlet_Size', style='Outlet_Size',col='Outlet_Size',data=data_BM[:100]);

# %% [markdown]
# ## Advance categorical plots in seaborn
#
# For categorical variables we have three different families in seaborn.
#
#  * **Categorical scatterplots:**
#
#       * stripplot()(with kind="strip":the default)
#       * swarmplot()(with kind="swarm")
#
#  * **Categorical distribution plots:**
#
#     * boxplot()(with kind="box")
#     * violinplot()(with kind="violin")
#
#  * **Categorical estimate plots:**
#
#     * barplot()(with kind="bar")

# %% [markdown]
# **a.Categorical scatterplots**
#
# **Strip plot**
#
# * Draws a scatterplot where one variable is categorical.
# * You can create this by passing **kind=strip** in the catplot()

# %%
sns.catplot(x="Outlet_Size", y="Item_Outlet_Sales", kind="strip",data=data_BM[:250])

# %% [markdown]
# **Swarm plot**
#  * This function is similar to stripplot(), but the points are adjusted(only along the categorical axis) so that they dont overlap.
#
#  * This gives a better representation of the distribution of values, but it doesnt scale well to large numbers of observations.This style of plot is called a "beeswarm"
#
#  * You can create this by passing **kind=swarm** in the catplot()

# %%
sns.catplot(x="Outlet_Size", y="Item_Outlet_Sales", kind="swarm",data=data_BM[:250]);

# %% [markdown]
# **Box Plots**
# * Box plot shows the three quartile values of the distribution along with extreme values
# * The "whiskers" extend to points that lie within 1.5 IQRS of the lower and upper quartile, and then observations that fall outside this range are displayed independently.
# * This means that each value in the boxplot corresponds to an actual observation in the data

# %%
sns.catplot(x="Outlet_Size", y="Item_Outlet_Sales", kind="box",data=data_BM[:250]);

# %% [markdown]
# **Violin plots**

# %%
sns.catplot(x="Outlet_Size", y="Item_Outlet_Sales", kind="violin",data=data_BM[:250]);
